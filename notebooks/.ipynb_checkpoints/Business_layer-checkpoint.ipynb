# %%
# Core
import pandas as pd
import numpy as np

# Model loading
import joblib

# (Optional) Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import joblib

model = joblib.load('../models/churn_model.pkl')

# %%
df_full = pd.read_csv('../data/processed_data.csv')

# same preprocessing fix if needed
for col in df_full.columns:
    if str(df_full[col].dtype) == 'string':
        df_full[col] = df_full[col].astype('object')

X_full = df_full.drop('Churn', axis=1)

df_full['churn_probability'] = model.predict_proba(X_full)[:, 1]

# %%
df_full['business_score'] = df_full['churn_probability'] * df_full['CLV']

df_full = df_full.sort_values(by='business_score', ascending=False)

top_customers = df_full.head(50)
top_customers
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2874  4550-VBOFE    Male              1     Yes         No      70
# 6023  9090-SGQXL    Male              1     Yes         No      68
# 2604  4446-BZKHU    Male              0     Yes         No      61
# 4076  0324-BRPCJ  Female              1     Yes         No      68
# 339   1343-EHPYB    Male              0     Yes         No      63
# 2272  3571-RFHAR    Male              0      No         No      65
# 4387  5502-RLUYV  Female              0     Yes        Yes      69
# 4067  0946-CLJTI    Male              1     Yes         No      58
# 634   7207-RMRDB  Female              0     Yes        Yes      65
# 3195  0895-DQHEW    Male              0     Yes         No      54
# 1335  3838-OZURD    Male              0     Yes         No      66
# 3325  8276-MQBYC    Male              1      No         No      51
# 7012  1035-IPQPU  Female              1     Yes         No      63
# ...

# %%
final_cols = [
    'customerID',
    'tenure',
    'MonthlyCharges',
    'TotalCharges',
    'CLV',
    'churn_probability',
    'business_score',
    'Contract',
    'InternetService',
    'num_services'
]

top_customers_final = top_customers[final_cols]
top_customers_final.head(10)
# Out:
#       customerID  tenure  MonthlyCharges  TotalCharges      CLV  \
# 2874  4550-VBOFE      70          102.95       7101.50  7206.50
# 6023  9090-SGQXL      68          105.30       7299.65  7160.40
# 2604  4446-BZKHU      61          105.55       6281.45  6438.55
# 4076  0324-BRPCJ      68          100.20       6851.65  6813.60
# 339   1343-EHPYB      63          103.40       6603.00  6514.20
# 2272  3571-RFHAR      65          109.15       6941.20  7094.75
# 4387  5502-RLUYV      69          103.95       7446.90  7172.55
# 4067  0946-CLJTI      58           98.70       5812.60  5724.60
# 634   7207-RMRDB      65          105.50       6985.65  6857.50
# 3195  0895-DQHEW      54          104.30       5278.15  5632.20
#
#       churn_probability  business_score        Contract InternetService  \
# 2874           0.596046     4295.406722  Month-to-month     Fiber optic
# 6023           0.592027     4239.153064  Month-to-month     Fiber optic
# ...

# %%
def recommend_action(row):
    if row['Contract'] == 'Month-to-month':
        return 'Offer long-term contract discount'
    elif row['MonthlyCharges'] > 80:
        return 'Give pricing retention offer'
    elif row['num_services'] <= 2:
        return 'Offer bundle upgrade'
    else:
        return 'Retention call by support team'

df_full['recommended_action'] = df_full.apply(recommend_action, axis=1)

top_customers = df_full.sort_values(by='business_score', ascending=False).head(50)

final_cols = [
    'customerID',
    'tenure',
    'MonthlyCharges',
    'CLV',
    'churn_probability',
    'business_score',
    'Contract',
    'num_services',
    'recommended_action'
]

top_customers_final = top_customers[final_cols]
top_customers_final.head(10)
# Out:
#       customerID  tenure  MonthlyCharges      CLV  churn_probability  \
# 2874  4550-VBOFE      70          102.95  7206.50           0.596046
# 6023  9090-SGQXL      68          105.30  7160.40           0.592027
# 2604  4446-BZKHU      61          105.55  6438.55           0.614296
# 4076  0324-BRPCJ      68          100.20  6813.60           0.579377
# 339   1343-EHPYB      63          103.40  6514.20           0.598630
# 2272  3571-RFHAR      65          109.15  7094.75           0.534099
# 4387  5502-RLUYV      69          103.95  7172.55           0.527655
# 4067  0946-CLJTI      58           98.70  5724.60           0.656795
# 634   7207-RMRDB      65          105.50  6857.50           0.545091
# 3195  0895-DQHEW      54          104.30  5632.20           0.654848
#
#       business_score        Contract  num_services  \
# 2874     4295.406722  Month-to-month             5
# 6023     4239.153064  Month-to-month             5
# ...

# %%
top_customers_final.to_csv('../data/top_50_customers_to_target.csv', index=False)

# %%
import matplotlib.pyplot as plt

top10 = top_customers_final.head(10)

plt.figure(figsize=(10,6))
plt.bar(top10['customerID'], top10['business_score'])
plt.xticks(rotation=45)
plt.ylabel('Business Score')
plt.xlabel('Customer ID')
plt.title('Top 10 Customers to Target')
plt.tight_layout()
plt.show()

# %% [markdown]
# * “After predicting churn probability, we added a business prioritization layer by combining churn risk with estimated customer lifetime value. This allowed us to rank customers by potential revenue impact and recommend retention actions for the top-risk, high-value customers.”
#
# And for why this matters:
#
# “A company usually cannot target everyone, so this layer helps allocate retention budget efficiently.”
